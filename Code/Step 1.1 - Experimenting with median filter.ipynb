# %% [markdown]
# ## Experimenting with using median rather than mean absorbance to get values from raw data. How does this affect the reps?

# %%
from fopt_toolkit import fopt_toolkit as fp
import glob
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
averaged_files_path = fp.make_dir('Data/2_1_summary_stats/')

# %%
file_list = sorted(glob.glob(averaged_files_path+'/*.csv'))

# %%
file_list
# Out:
# ['/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_a_1_T20_6.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_a_2_T20_9.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_a_3_T20_9.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_c_1_T20_6.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_c_2_T20_6.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_070718_sea_cal_c_3_T20_6.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_071318_bai_cal_a_1_T23_8.csv',
#  '/Users/Petrichor/Documents/FreshwatersOpticsToolkit/Data/2_1_summary_stats/AC9_071318_bai_cal_a_2_T24_1.csv',
# ...
